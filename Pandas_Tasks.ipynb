# %% [markdown]
# <a href="https://colab.research.google.com/github/mudassaralye/NumPy/blob/main/Pandas_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Pandas Series

# %%
pd.Series([1,4,9,6,7],['a','x','c','2','e'])
# Out:
# a    1
# x    4
# c    9
# 2    6
# e    7
# dtype: int64

# %%
data={
    'Bilal':42,
    'Ayesha':38,
    'Hadia':39
}
pd.Series(data)
# Out:
# Bilal     42
# Ayesha    38
# Hadia     39
# dtype: int64

# %% [markdown]
# Pandas DataFrame

# %%
data={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']
}
df = pd.DataFrame(data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.index=['a','b','c','d','e','f']
df
# Out:
#         day  temperature  windspeed  event
# a  1/1/2017           32          6   Rain
# b  1/2/2017           35          7  Sunny
# c  1/3/2017           28          2   Snow
# d  1/4/2017           24          7   Snow
# e  1/5/2017           32          4   Rain
# f  1/6/2017           31          2  Sunny

# %%
mean=df['temperature'].mean()
max=df['temperature'].max()
min=df['temperature'].min()
print('Temperature: Mean:',mean,', Maximum:',max,', Minimum:',min)
# Out:
# Temperature: Mean: 30.333333333333332 , Maximum: 35 , Minimum: 24

# %%
df=pd.read_csv('/content/people.csv',usecols=["First Name","Sex","Email","Phone","Job Title"])
df.set_index(["Sex", "Job Title"], inplace=True)
df=df.drop([['Male','Games developer'],['Male','Veterinary surgeon']])
df.to_csv('/content/NewPeople.csv')
df
# Out:
#                                 First Name                       Email  \
# Sex    Job Title
# Female Phytotherapist              Phillip       bethany14@example.com
# Male   Homeopath                  Kristine       bthompson@example.com
#        Market researcher           Yesenia   kaitlinkaiser@example.com
#        Waste management officer       Erin         tconner@example.org
# Female Intelligence analyst      Katherine     conniecowan@example.com
# ...                                    ...                         ...
#        Software engineer            Dennis         bmartin@example.org
#        Barrister                     Steve       latasha46@example.net
# Male   Police officer               Wesley        regina11@example.org
# Female Broadcast journalist         Summer  alexiscantrell@example.org
# Male   IT sales professional        Mariah       pcopeland@example.org
#
#                                                  Phone
# Sex    Job Title
# ...

# %%
df=pd.read_excel('/content/SampleWork.xlsx',sheet_name=0,usecols=[0,3],skiprows=1,header=1)
df.to_excel('/content/NewSheet.xlsx', index=False)
df
# Out:
#     Bilal  90
# 0  Sufyan  85
# 1   Saiqa  80
# 2   Aimen  75

# %%
data={
    'Name':['Sonia','Bilal','Hifza','Kabir','Jazim'],
    'Age':[27,24,22,32,33],
    'Address':['Lahore','Karachi','Sialkot','Peshawar','lhr'],
    'Qualification':['Msc','MA','MCA','Phd','bsc']
}
AICP_DF=pd.DataFrame(data)
df1=AICP_DF[['Name','Qualification']]
AICP_DF['Height']=[5.1,6.2,5.1,5.2,5.1]
AICP_DF.set_index('Name',inplace=True)
row_hifza=AICP_DF.loc['Hifza']
row_index_3=AICP_DF.iloc[3]
AICP_DF.drop('Bilal',inplace=True)

print("AICP_DF:")
print(AICP_DF)
print("\ndf1:")
print(df1)
print("\nRow with index 'Hifza':")
print(row_hifza)
print("\nRow with index 3:")
print(row_index_3)
# Out:
# AICP_DF:
#        Age   Address Qualification  Height
# Name
# Sonia   27    Lahore           Msc     5.1
# Hifza   22   Sialkot           MCA     5.1
# Kabir   32  Peshawar           Phd     5.2
# Jazim   33       lhr           bsc     5.1
#
# df1:
#     Name Qualification
# 0  Sonia           Msc
# 1  Bilal            MA
# 2  Hifza           MCA
# 3  Kabir           Phd
# 4  Jazim           bsc
#
# Row with index 'Hifza':
# Age                   22
# Address          Sialkot
# Qualification        MCA
# Height               5.1
# Name: Hifza, dtype: object
#
# Row with index 3:
# Age                    32
# Address          Peshawar
# Qualification         Phd
# Height                5.2
# Name: Kabir, dtype: object
